# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
false = pd.read_csv('./fp/a89.02774306423395e10s20002d10svm_init_false.csv')
true = pd.read_csv('./fp/a92.10197450637341e10s20002d10svm_init_true.csv')
plt.figure(); 
false['loss_list'].plot();
true['loss_list'].plot();
plt.title('loss comparison')
# Out:
# Text(0.5, 1.0, 'loss comparison')

# %%
plt.figure(); 
false['val_acc_list'].plot();
true['val_acc_list'].plot();
plt.title('validation accuracy')
# Out:
# Text(0.5, 1.0, 'validation accuracy')

# %%
plt.figure(); 
false['train_acc_list'].plot();
true['train_acc_list'].plot();
plt.title('training accuracy')
# Out:
# Text(0.5, 1.0, 'training accuracy')

# %%
false
# Out:
#    Unnamed: 0  loss_list  val_acc_list  train_acc_list
# 0           0  43.401434     60.084979       56.589147
# 1           1  41.157639     69.957511       74.418605
# 2           2  39.107165     70.357411       77.519380
# 3           3  37.918362     71.657086       77.519380
# 4           4  32.380459     76.555861       90.697674
# 5           5  27.274061     80.629843       94.573643
# 6           6  25.482900     84.003999       92.248062
# 7           7  24.577885     86.703324       93.023256
# 8           8  24.168239     88.877781       91.472868
# 9           9  23.755562     89.027743       96.124031
